# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushrai/Reinforcement_learning/blob/master/Deep_Reinforcement_Learning_with_Open_AI_Gym(keras).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
from collections import deque
import gym
import numpy as np
import random
import keras
import cv2
from keras.models import load_model, Sequential
from keras.layers.convolutional import Convolution2D
from keras.optimizers import Adam
from keras.layers.core import Activation, Dropout, Flatten, Dense
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# memory for store experience
class ReplayBuffer:
    """Constructs a buffer object that stores the past moves
    and samples a set of subsamples"""

    def __init__(self, buffer_size):
        self.buffer_size = buffer_size
        self.count = 0
        self.buffer = deque()

    def add(self, s, a, r, d, s2):
        """Add an experience to the buffer"""
        # S represents current state, a is action,
        # r is reward, d is whether it is the end, 
        # and s2 is next state
        experience = (s, a, r, d, s2)
        if self.count < self.buffer_size:
            self.buffer.append(experience)
            self.count += 1
        else:
            self.buffer.popleft()
            self.buffer.append(experience)

    def size(self):
        return self.count

    def sample(self, batch_size):
        """Samples a total of elements equal to batch_size from buffer
        if buffer contains enough elements. Otherwise return all elements"""

        batch = []

        if self.count < batch_size:
            batch = random.sample(self.buffer, self.count)
        else:
            batch = random.sample(self.buffer, batch_size)

        # Maps each experience in batch in batches of states, actions, rewards
        # and new states
        s_batch, a_batch, r_batch, d_batch, s2_batch = list(map(np.array, list(zip(*batch))))

        return s_batch, a_batch, r_batch, d_batch, s2_batch

    def clear(self):
        self.buffer.clear()
        self.count = 0

# %%
DECAY_RATE = 0.99
BUFFER_SIZE = 40000
MINIBATCH_SIZE = 64
TOT_FRAME = 3000000
EPSILON_DECAY = 1000000
MIN_OBSERVATION = 3000
FINAL_EPSILON = 0.09
INITIAL_EPSILON = 0.8
NUM_ACTIONS = 6
TAU = 0.01
# Number of frames to throw into network
NUM_FRAMES = 3

# %%
class DeepQ(object):
    """Constructs the desired deep q learning network"""
    def __init__(self):
        self.construct_q_network()

    def construct_q_network(self):
        # Uses the network architecture found in DeepMind paper
        self.model = Sequential()
        self.model.add(Convolution2D(32, 8, 8, subsample=(4, 4), input_shape=(84, 84, NUM_FRAMES)))
        self.model.add(Activation('relu'))
        self.model.add(Convolution2D(64, 4, 4, subsample=(2, 2)))
        self.model.add(Activation('relu'))
        self.model.add(Convolution2D(64, 3, 3))
        self.model.add(Activation('relu'))
        self.model.add(Flatten())
        self.model.add(Dense(512))
        self.model.add(Activation('relu'))
        self.model.add(Dense(NUM_ACTIONS))
        self.model.compile(loss='mse', optimizer=Adam(lr=0.00001))

        # Creates a target network as described in DeepMind paper
        self.target_model = Sequential()
        self.target_model.add(Convolution2D(32, 8, 8, subsample=(4, 4), input_shape=(84, 84, NUM_FRAMES)))
        self.target_model.add(Activation('relu'))
        self.target_model.add(Convolution2D(64, 4, 4, subsample=(2, 2)))
        self.target_model.add(Activation('relu'))
        self.target_model.add(Convolution2D(64, 3, 3))
        self.target_model.add(Activation('relu'))
        self.target_model.add(Flatten())
        self.target_model.add(Dense(512))
        self.model.add(Activation('relu'))
        self.target_model.add(Dense(NUM_ACTIONS))
        self.target_model.compile(loss='mse', optimizer=Adam(lr=0.00001))
        self.target_model.set_weights(self.model.get_weights())
    def save_network(self, path):
        # Saves model at specified path as h5 file
        self.model.save(path)
        print("Successfully saved network.")

    def load_network(self, path):
        self.model = load_model(path)
        print("Succesfully loaded network.")

    def target_train(self):
        model_weights = self.model.get_weights()
        target_model_weights = self.target_model.get_weights()
        for i in range(len(model_weights)):
            target_model_weights[i] = TAU * model_weights[i] + (1 - TAU) * target_model_weights[i]
        self.target_model.set_weights(target_model_weights)

    def predict_movement(self, data, epsilon):
        """Predict movement of game controler where is epsilon
        probability randomly move."""
        q_actions = self.model.predict(data.reshape(1, 84, 84, NUM_FRAMES), batch_size = 1)
        opt_policy = np.argmax(q_actions)
        rand_val = np.random.random()
        if rand_val < epsilon:
            opt_policy = np.random.randint(0, NUM_ACTIONS)
        return opt_policy, q_actions[0, opt_policy]
    
    def predict_movement(self, data, epsilon):
        """Predict movement of game controler where is epsilon
        probability randomly move."""
        q_actions = self.model.predict(data.reshape(1, 84, 84, NUM_FRAMES), batch_size = 1)
        opt_policy = np.argmax(q_actions)
        rand_val = np.random.random()
        if rand_val < epsilon:
            opt_policy = np.random.randint(0, NUM_ACTIONS)
        return opt_policy, q_actions[0, opt_policy]

    def train(self, s_batch, a_batch, r_batch, d_batch, s2_batch, observation_num):
        """Trains network to fit given parameters"""
        batch_size = s_batch.shape[0]
        targets = np.zeros((batch_size, NUM_ACTIONS))

        for i in range(batch_size):
            targets[i] = self.model.predict(s_batch[i].reshape(1, 84, 84, NUM_FRAMES), batch_size = 1)
            fut_action = self.target_model.predict(s2_batch[i].reshape(1, 84, 84, NUM_FRAMES), batch_size = 1)
            targets[i, a_batch[i]] = r_batch[i]
            if d_batch[i] == False:
                targets[i, a_batch[i]] += DECAY_RATE * np.max(fut_action)

        loss = self.model.train_on_batch(s_batch, targets)

        # Print the loss every 10 iterations.
        if observation_num % 10 == 0:
            print("We had a loss equal to ", loss)

    def save_network(self, path):
        # Saves model at specified path as h5 file
        self.model.save(path)
        print("Successfully saved network.")

    def load_network(self, path):
        self.model = load_model(path)
        print("Succesfully loaded network.")

    def target_train(self):
        model_weights = self.model.get_weights()
        target_model_weights = self.target_model.get_weights()
        for i in range(len(model_weights)):
            target_model_weights[i] = TAU * model_weights[i] + (1 - TAU) * target_model_weights[i]
        self.target_model.set_weights(target_model_weights)

# %%
class SpaceInvader(object):

    def __init__(self, mode):
        self.env = gym.make('SpaceInvaders-v0')
        self.env.reset()
        self.replay_buffer = ReplayBuffer(BUFFER_SIZE)

        # Construct appropriate network based on flags
        if mode == "DDQN":
            self.deep_q = DeepQ()
        elif mode == "DQN":
            self.deep_q = DuelQ()

        # A buffer that keeps the last 3 images
        self.process_buffer = []
        # Initialize buffer with the first frame
        s1, r1, _, _ = self.env.step(0)
        s2, r2, _, _ = self.env.step(0)
        s3, r3, _, _ = self.env.step(0)
        self.process_buffer = [s1, s2, s3]

    def load_network(self, path):
        self.deep_q.load_network(path)

    def convert_process_buffer(self):
        """Converts the list of NUM_FRAMES images in the process buffer
        into one training sample"""
        black_buffer = [cv2.resize(cv2.cvtColor(x, cv2.COLOR_RGB2GRAY), (84, 90)) for x in self.process_buffer]
        black_buffer = [x[1:85, :, np.newaxis] for x in black_buffer]
        return np.concatenate(black_buffer, axis=2)

    def train(self, num_frames):
        observation_num = 0
        curr_state = self.convert_process_buffer()
        epsilon = INITIAL_EPSILON
        alive_frame = 0
        total_reward = 0

        while observation_num < num_frames:
            print("Iteration No:",observation_num)
            if observation_num % 1000 == 999:
                print(("Executing loop %d" %observation_num))

            # Slowly decay the learning rate
            if epsilon > FINAL_EPSILON:
                epsilon -= (INITIAL_EPSILON-FINAL_EPSILON)/EPSILON_DECAY

            initial_state = self.convert_process_buffer()
            self.process_buffer = []

            predict_movement, predict_q_value = self.deep_q.predict_movement(curr_state, epsilon)

            reward, done = 0, False
            for i in range(NUM_FRAMES):
                temp_observation, temp_reward, temp_done, _ = self.env.step(predict_movement)
                reward += temp_reward
                self.process_buffer.append(temp_observation)
                done = done | temp_done

            if observation_num % 10 == 0:
                print("We predicted a q value of ", predict_q_value)

            if done:
                print("Lived with maximum time ", alive_frame)
                print("Earned a total of reward equal to ", total_reward)
                self.env.reset()
                alive_frame = 0
                total_reward = 0

            new_state = self.convert_process_buffer()
            self.replay_buffer.add(initial_state, predict_movement, reward, done, new_state)
            total_reward += reward

            if self.replay_buffer.size() > MIN_OBSERVATION:
                s_batch, a_batch, r_batch, d_batch, s2_batch = self.replay_buffer.sample(MINIBATCH_SIZE)
                self.deep_q.train(s_batch, a_batch, r_batch, d_batch, s2_batch, observation_num)
                self.deep_q.target_train()

            # Save the network every 100000 iterations
            if observation_num % 10000 == 9999:
                print("Saving Network")
                self.deep_q.save_network("saved.h5")

            alive_frame += 1
            observation_num += 1

    def simulate(self, path = "", save = False):
        """Simulates game"""
        done = False
        tot_award = 0
        if save:
            self.env.monitor.start(path, force=True)
        self.env.reset()
        self.env.render()
        while not done:
            state = self.convert_process_buffer()
            predict_movement = self.deep_q.predict_movement(state, 0)[0]
            self.env.render()
            observation, reward, done, _ = self.env.step(predict_movement)
            tot_award += reward
            self.process_buffer.append(observation)
            self.process_buffer = self.process_buffer[1:]
        if save:
            self.env.monitor.close()
    def simulate2(self, path = "", save = False):
        """Simulates game"""
        done = False
        tot_award = 0
        if save:
          self.env.monitor.start(path, force=True)
        self.env.reset()
        self.show_state(self.env)
        while not done:
            state = self.convert_process_buffer()
            predict_movement = self.deep_q.predict_movement(state, 0)[0]
            self.show_state(self.env)
            observation, reward, done, _ = self.env.step(predict_movement)
            tot_award += reward
            self.process_buffer.append(observation)
            self.process_buffer = self.process_buffer[1:]
        if save:
            self.env.monitor.close()

    def show_state(self,env, step=0, info=""):
        plt.figure(5,figsize=(10,10))
        plt.clf()
        plt.imshow(env.render(mode='rgb_array'))
        plt.axis('off')
        display.clear_output(wait=True)
        display.display(plt.gcf())

    def calculate_mean(self, num_samples = 100):
        reward_list = []
        print("Printing scores of each trial")
        for i in range(num_samples):
            done = False
            tot_award = 0
            self.env.reset()
            while not done:
                state = self.convert_process_buffer()
                predict_movement = self.deep_q.predict_movement(state, 0.0)[0]
                observation, reward, done, _ = self.env.step(predict_movement)
                tot_award += reward
                self.process_buffer.append(observation)
                self.process_buffer = self.process_buffer[1:]
            print(tot_award)
            reward_list.append(tot_award)
        return np.mean(reward_list), np.std(reward_list)

# %%
game_instance = SpaceInvader("DDQN")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), input_shape=(84, 84, 3..., strides=(4, 4))`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), strides=(2, 2))`
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), input_shape=(84, 84, 3..., strides=(4, 4))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), strides=(2, 2))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`

# %%
 NUM_FRAME = 000
 game_instance.train(NUM_FRAME)
# Out:
# Iteration No: 0
# We predicted a q value of  4.275073
# Iteration No: 1
# Iteration No: 2
# Iteration No: 3
# Iteration No: 4
# Iteration No: 5
# Iteration No: 6
# Iteration No: 7
# Iteration No: 8
# Iteration No: 9
# Iteration No: 10
# We predicted a q value of  0.0
# Iteration No: 11
# Iteration No: 12
# Iteration No: 13
# Iteration No: 14
# Iteration No: 15
# Iteration No: 16
# Iteration No: 17
# Iteration No: 18
# Iteration No: 19
# Iteration No: 20
# We predicted a q value of  0.0
# Iteration No: 21
# Iteration No: 22
# Iteration No: 23
# Iteration No: 24
# Iteration No: 25
# Iteration No: 26
# Iteration No: 27
# Iteration No: 28
# Iteration No: 29
# Iteration No: 30
# We predicted a q value of  4.275073
# Iteration No: 31
# Iteration No: 32
# Iteration No: 33
# Iteration No: 34
# Iteration No: 35
# Iteration No: 36
# Iteration No: 37
# Iteration No: 38
# Iteration No: 39
# Iteration No: 40
# We predicted a q value of  4.275073
# Iteration No: 41
# Iteration No: 42
# Iteration No: 43
# Iteration No: 44
# Iteration No: 45
# Iteration No: 46
# Iteration No: 47
# Iteration No: 48
# Iteration No: 49
# Iteration No: 50
# We predicted a q value of  4.275073
# Iteration No: 51
# Iteration No: 52
# Iteration No: 53
# Iteration No: 54
# Iteration No: 55
# Iteration No: 56
# Iteration No: 57
# Iteration No: 58
# Iteration No: 59
# Iteration No: 60
# We predicted a q value of  0.0
# Iteration No: 61
# Iteration No: 62
# Iteration No: 63
# Iteration No: 64
# Iteration No: 65
# Iteration No: 66
# Iteration No: 67
# Iteration No: 68
# Iteration No: 69
# Iteration No: 70
# We predicted a q value of  0.0
# Iteration No: 71
# Iteration No: 72
# Iteration No: 73
# Iteration No: 74
# Iteration No: 75
# Iteration No: 76
# Iteration No: 77
# Iteration No: 78
# Iteration No: 79
# Iteration No: 80
# We predicted a q value of  0.0
# Iteration No: 81
# Iteration No: 82
# Iteration No: 83
# Iteration No: 84
# Iteration No: 85
# Iteration No: 86
# Iteration No: 87
# Iteration No: 88
# Iteration No: 89
# Iteration No: 90
# We predicted a q value of  4.275073
# Iteration No: 91
# Iteration No: 92
# Iteration No: 93
# Iteration No: 94
# Iteration No: 95
# Iteration No: 96
# Iteration No: 97
# Iteration No: 98
# Iteration No: 99
# Iteration No: 100
# We predicted a q value of  0.0
# Iteration No: 101
# Iteration No: 102
# Iteration No: 103
# Iteration No: 104
# Iteration No: 105
# Iteration No: 106
# Iteration No: 107
# Iteration No: 108
# Iteration No: 109
# Iteration No: 110
# We predicted a q value of  0.0
# Iteration No: 111
# Iteration No: 112
# Iteration No: 113
# Iteration No: 114
# Iteration No: 115
# Iteration No: 116
# Iteration No: 117
# Iteration No: 118
# Iteration No: 119
# Iteration No: 120
# We predicted a q value of  4.275073
# Iteration No: 121
# Iteration No: 122
# Iteration No: 123
# Iteration No: 124
# Iteration No: 125
# Iteration No: 126
# Iteration No: 127
# Iteration No: 128
# Iteration No: 129
# Iteration No: 130
# We predicted a q value of  0.0
# Iteration No: 131
# Iteration No: 132
# Iteration No: 133
# Iteration No: 134
# Iteration No: 135
# Iteration No: 136
# Iteration No: 137
# Iteration No: 138
# Iteration No: 139
# Iteration No: 140
# We predicted a q value of  0.0
# Iteration No: 141
# Iteration No: 142
# Iteration No: 143
# Iteration No: 144
# Iteration No: 145
# Iteration No: 146
# Iteration No: 147
# Iteration No: 148
# Lived with maximum time  148
# Earned a total of reward equal to  20.0
# Iteration No: 149
# Iteration No: 150
# We predicted a q value of  0.0
# Iteration No: 151
# Iteration No: 152
# Iteration No: 153
# Iteration No: 154
# Iteration No: 155
# Iteration No: 156
# Iteration No: 157
# Iteration No: 158
# Iteration No: 159
# Iteration No: 160
# We predicted a q value of  0.0
# Iteration No: 161
# Iteration No: 162
# Iteration No: 163
# Iteration No: 164
# Iteration No: 165
# Iteration No: 166
# Iteration No: 167
# Iteration No: 168
# Iteration No: 169
# Iteration No: 170
# We predicted a q value of  4.275073
# Iteration No: 171
# Iteration No: 172
# Iteration No: 173
# Iteration No: 174
# Iteration No: 175
# Iteration No: 176
# Iteration No: 177
# Iteration No: 178
# Iteration No: 179
# Iteration No: 180
# We predicted a q value of  0.0
# Iteration No: 181
# Iteration No: 182
# Iteration No: 183
# Iteration No: 184
# Iteration No: 185
# Iteration No: 186
# Iteration No: 187
# Iteration No: 188
# Iteration No: 189
# Iteration No: 190
# We predicted a q value of  0.0
# Iteration No: 191
# Iteration No: 192
# Iteration No: 193
# Iteration No: 194
# Iteration No: 195
# Iteration No: 196
# Iteration No: 197
# Iteration No: 198
# Iteration No: 199
# Iteration No: 200
# We predicted a q value of  0.0
# Iteration No: 201
# Iteration No: 202
# Iteration No: 203
# Iteration No: 204
# Iteration No: 205
# Iteration No: 206
# Iteration No: 207
# Iteration No: 208
# Iteration No: 209
# Iteration No: 210
# We predicted a q value of  0.0
# Iteration No: 211
# Iteration No: 212
# Iteration No: 213
# Iteration No: 214
# Iteration No: 215
# Iteration No: 216
# Iteration No: 217
# Iteration No: 218
# Iteration No: 219
# Iteration No: 220
# We predicted a q value of  0.0
# Iteration No: 221
# Iteration No: 222
# Iteration No: 223
# Iteration No: 224
# Iteration No: 225
# Iteration No: 226
# Iteration No: 227
# Iteration No: 228
# Iteration No: 229
# Iteration No: 230
# We predicted a q value of  0.0
# Iteration No: 231
# Iteration No: 232
# Iteration No: 233
# Iteration No: 234
# Iteration No: 235
# Iteration No: 236
# Iteration No: 237
# Iteration No: 238
# Iteration No: 239
# Iteration No: 240
# We predicted a q value of  0.0
# Iteration No: 241
# Iteration No: 242
# Iteration No: 243
# Iteration No: 244
# Iteration No: 245
# Iteration No: 246
# Iteration No: 247
# Iteration No: 248
# Iteration No: 249
# Iteration No: 250
# We predicted a q value of  4.275073
# Iteration No: 251
# Iteration No: 252
# Iteration No: 253
# Iteration No: 254
# Iteration No: 255
# Iteration No: 256
# Iteration No: 257
# Iteration No: 258
# Iteration No: 259
# Iteration No: 260
# We predicted a q value of  4.275073
# Iteration No: 261
# Iteration No: 262
# Iteration No: 263
# Iteration No: 264
# Iteration No: 265
# Iteration No: 266
# Iteration No: 267
# Iteration No: 268
# Iteration No: 269
# Iteration No: 270
# We predicted a q value of  0.0
# Iteration No: 271
# Iteration No: 272
# Iteration No: 273
# Iteration No: 274
# Iteration No: 275
# Iteration No: 276
# Iteration No: 277
# Iteration No: 278
# Iteration No: 279
# Iteration No: 280
# We predicted a q value of  4.275073
# Iteration No: 281
# Iteration No: 282
# Iteration No: 283
# Iteration No: 284
# Iteration No: 285
# Iteration No: 286
# Iteration No: 287
# Iteration No: 288
# Iteration No: 289
# Iteration No: 290
# We predicted a q value of  4.275073
# Iteration No: 291
# Iteration No: 292
# Iteration No: 293
# Iteration No: 294
# Iteration No: 295
# Iteration No: 296
# Iteration No: 297
# Iteration No: 298
# Iteration No: 299
# Iteration No: 300
# We predicted a q value of  0.0
# Iteration No: 301
# Iteration No: 302
# Iteration No: 303
# Iteration No: 304
# Iteration No: 305
# Iteration No: 306
# Iteration No: 307
# Iteration No: 308
# Iteration No: 309
# Iteration No: 310
# We predicted a q value of  0.0
# Iteration No: 311
# Iteration No: 312
# Iteration No: 313
# Iteration No: 314
# Iteration No: 315
# Iteration No: 316
# Iteration No: 317
# Iteration No: 318
# Iteration No: 319
# Iteration No: 320
# We predicted a q value of  4.275073
# Iteration No: 321
# Iteration No: 322
# Iteration No: 323
# Iteration No: 324
# Iteration No: 325
# Iteration No: 326
# Iteration No: 327
# Iteration No: 328
# Iteration No: 329
# Iteration No: 330
# We predicted a q value of  4.275073
# Iteration No: 331
# Iteration No: 332
# Iteration No: 333
# Iteration No: 334
# Iteration No: 335
# Iteration No: 336
# Iteration No: 337
# Iteration No: 338
# Iteration No: 339
# Iteration No: 340
# We predicted a q value of  0.0
# Iteration No: 341
# Iteration No: 342
# Iteration No: 343
# Iteration No: 344
# Iteration No: 345
# Iteration No: 346
# Iteration No: 347
# Iteration No: 348
# Iteration No: 349
# Iteration No: 350
# We predicted a q value of  0.0
# Iteration No: 351
# Iteration No: 352
# Iteration No: 353
# Iteration No: 354
# Iteration No: 355
# Iteration No: 356
# Iteration No: 357
# Iteration No: 358
# Iteration No: 359
# Iteration No: 360
# We predicted a q value of  4.275073
# Iteration No: 361
# Iteration No: 362
# Iteration No: 363
# Iteration No: 364
# Iteration No: 365
# Iteration No: 366
# Iteration No: 367
# Iteration No: 368
# Iteration No: 369
# Iteration No: 370
# We predicted a q value of  0.0
# Iteration No: 371
# Iteration No: 372
# Lived with maximum time  224
# Earned a total of reward equal to  120.0
# Iteration No: 373
# Iteration No: 374
# Iteration No: 375
# Iteration No: 376
# Iteration No: 377
# Iteration No: 378
# Iteration No: 379
# Iteration No: 380
# We predicted a q value of  4.275073
# Iteration No: 381
# Iteration No: 382
# Iteration No: 383
# Iteration No: 384
# Iteration No: 385
# Iteration No: 386
# Iteration No: 387
# Iteration No: 388
# Iteration No: 389
# Iteration No: 390
# We predicted a q value of  4.275073
# Iteration No: 391
# Iteration No: 392
# Iteration No: 393
# Iteration No: 394
# Iteration No: 395
# Iteration No: 396
# Iteration No: 397
# Iteration No: 398
# Iteration No: 399
# Iteration No: 400
# We predicted a q value of  4.275073
# Iteration No: 401
# Iteration No: 402
# Iteration No: 403
# Iteration No: 404
# Iteration No: 405
# Iteration No: 406
# Iteration No: 407
# Iteration No: 408
# Iteration No: 409
# Iteration No: 410
# We predicted a q value of  0.0
# Iteration No: 411
# Iteration No: 412
# Iteration No: 413
# Iteration No: 414
# Iteration No: 415
# Iteration No: 416
# Iteration No: 417
# Iteration No: 418
# Iteration No: 419
# Iteration No: 420
# We predicted a q value of  0.0
# Iteration No: 421
# Iteration No: 422
# Iteration No: 423
# Iteration No: 424
# Iteration No: 425
# Iteration No: 426
# Iteration No: 427
# Iteration No: 428
# Iteration No: 429
# Iteration No: 430
# We predicted a q value of  0.0
# Iteration No: 431
# Iteration No: 432
# Iteration No: 433
# Iteration No: 434
# Iteration No: 435
# Iteration No: 436
# Iteration No: 437
# Iteration No: 438
# Iteration No: 439
# Iteration No: 440
# We predicted a q value of  0.0
# Iteration No: 441
# Iteration No: 442
# Iteration No: 443
# Iteration No: 444
# Iteration No: 445
# Iteration No: 446
# Iteration No: 447
# Iteration No: 448
# Iteration No: 449
# Iteration No: 450
# We predicted a q value of  4.275073
# Iteration No: 451
# Iteration No: 452
# Iteration No: 453
# Iteration No: 454
# Iteration No: 455
# Iteration No: 456
# Iteration No: 457
# Iteration No: 458
# Iteration No: 459
# Iteration No: 460
# We predicted a q value of  4.275073
# Iteration No: 461
# Iteration No: 462
# Iteration No: 463
# Iteration No: 464
# Iteration No: 465
# Iteration No: 466
# Iteration No: 467
# Iteration No: 468
# Iteration No: 469
# Iteration No: 470
# We predicted a q value of  0.0
# Iteration No: 471
# Iteration No: 472
# Iteration No: 473
# Iteration No: 474
# Iteration No: 475
# Iteration No: 476
# Iteration No: 477
# Iteration No: 478
# Iteration No: 479
# Iteration No: 480
# We predicted a q value of  0.0
# Iteration No: 481
# Iteration No: 482
# Iteration No: 483
# Iteration No: 484
# Iteration No: 485
# Iteration No: 486
# Iteration No: 487
# Iteration No: 488
# Iteration No: 489
# Iteration No: 490
# We predicted a q value of  4.275073
# Iteration No: 491
# Iteration No: 492
# Iteration No: 493
# Iteration No: 494
# Iteration No: 495
# Iteration No: 496
# Iteration No: 497
# Iteration No: 498
# Iteration No: 499
# Iteration No: 500
# We predicted a q value of  4.275073
# Iteration No: 501
# Iteration No: 502
# Iteration No: 503
# Iteration No: 504
# Iteration No: 505
# Iteration No: 506
# Iteration No: 507
# Iteration No: 508
# Iteration No: 509
# Iteration No: 510
# We predicted a q value of  0.0
# Iteration No: 511
# Iteration No: 512
# Iteration No: 513
# Iteration No: 514
# Iteration No: 515
# Iteration No: 516
# Iteration No: 517
# Iteration No: 518
# Iteration No: 519
# Iteration No: 520
# We predicted a q value of  0.0
# Iteration No: 521
# Iteration No: 522
# Iteration No: 523
# Iteration No: 524
# Iteration No: 525
# Iteration No: 526
# Iteration No: 527
# Iteration No: 528
# Iteration No: 529
# Iteration No: 530
# We predicted a q value of  4.275073
# Iteration No: 531
# Iteration No: 532
# Iteration No: 533
# Iteration No: 534
# Iteration No: 535
# Iteration No: 536
# Iteration No: 537
# Iteration No: 538
# Iteration No: 539
# Iteration No: 540
# We predicted a q value of  0.0
# Iteration No: 541
# Iteration No: 542
# Iteration No: 543
# Iteration No: 544
# Iteration No: 545
# Iteration No: 546
# Iteration No: 547
# Iteration No: 548
# Iteration No: 549
# Iteration No: 550
# We predicted a q value of  0.0
# Iteration No: 551
# Iteration No: 552
# Iteration No: 553
# Iteration No: 554
# Iteration No: 555
# Iteration No: 556
# Iteration No: 557
# Iteration No: 558
# Iteration No: 559
# Iteration No: 560
# We predicted a q value of  0.0
# Iteration No: 561
# Iteration No: 562
# Iteration No: 563
# Iteration No: 564
# Iteration No: 565
# Iteration No: 566
# Iteration No: 567
# Iteration No: 568
# Iteration No: 569
# Iteration No: 570
# We predicted a q value of  0.0
# Iteration No: 571
# Iteration No: 572
# Iteration No: 573
# Iteration No: 574
# Iteration No: 575
# Iteration No: 576
# Iteration No: 577
# Iteration No: 578
# Iteration No: 579
# Iteration No: 580
# We predicted a q value of  0.0
# Iteration No: 581
# Iteration No: 582
# Iteration No: 583
# Iteration No: 584
# Iteration No: 585
# Iteration No: 586
# Iteration No: 587
# Iteration No: 588
# Iteration No: 589
# Iteration No: 590
# We predicted a q value of  0.0
# Iteration No: 591
# Iteration No: 592
# Iteration No: 593
# Iteration No: 594
# Iteration No: 595
# Iteration No: 596
# Iteration No: 597
# Iteration No: 598
# Iteration No: 599
# Iteration No: 600
# We predicted a q value of  0.0
# Iteration No: 601
# Iteration No: 602
# Iteration No: 603
# Iteration No: 604
# Iteration No: 605
# Iteration No: 606
# Iteration No: 607
# Iteration No: 608
# Iteration No: 609
# Iteration No: 610
# We predicted a q value of  4.275073
# Iteration No: 611
# Iteration No: 612
# Iteration No: 613
# Iteration No: 614
# Iteration No: 615
# Iteration No: 616
# Iteration No: 617
# Iteration No: 618
# Iteration No: 619
# Iteration No: 620
# We predicted a q value of  4.275073
# Iteration No: 621
# Iteration No: 622
# Iteration No: 623
# Iteration No: 624
# Iteration No: 625
# Iteration No: 626
# Iteration No: 627
# Iteration No: 628
# Iteration No: 629
# Iteration No: 630
# We predicted a q value of  0.0
# Iteration No: 631
# Iteration No: 632
# Iteration No: 633
# Iteration No: 634
# Iteration No: 635
# Iteration No: 636
# Iteration No: 637
# Iteration No: 638
# Iteration No: 639
# Iteration No: 640
# We predicted a q value of  0.0
# Iteration No: 641
# Iteration No: 642
# Iteration No: 643
# Iteration No: 644
# Iteration No: 645
# Iteration No: 646
# Iteration No: 647
# Iteration No: 648
# Iteration No: 649
# Iteration No: 650
# We predicted a q value of  0.0
# Iteration No: 651
# Iteration No: 652
# Iteration No: 653
# Iteration No: 654
# Iteration No: 655
# Iteration No: 656
# Iteration No: 657
# Iteration No: 658
# Iteration No: 659
# Iteration No: 660
# We predicted a q value of  0.0
# Iteration No: 661
# Iteration No: 662
# Iteration No: 663
# Lived with maximum time  291
# Earned a total of reward equal to  245.0
# Iteration No: 664
# Iteration No: 665
# Iteration No: 666
# Iteration No: 667
# Iteration No: 668
# Iteration No: 669
# Iteration No: 670
# We predicted a q value of  0.0
# Iteration No: 671
# Iteration No: 672
# Iteration No: 673
# Iteration No: 674
# Iteration No: 675
# Iteration No: 676
# Iteration No: 677
# Iteration No: 678
# Iteration No: 679
# Iteration No: 680
# We predicted a q value of  0.0
# Iteration No: 681
# Iteration No: 682
# Iteration No: 683
# Iteration No: 684
# Iteration No: 685
# Iteration No: 686
# Iteration No: 687
# Iteration No: 688
# Iteration No: 689
# Iteration No: 690
# We predicted a q value of  4.275073
# Iteration No: 691
# Iteration No: 692
# Iteration No: 693
# Iteration No: 694
# Iteration No: 695
# Iteration No: 696
# Iteration No: 697
# Iteration No: 698
# Iteration No: 699
# Iteration No: 700
# We predicted a q value of  0.0
# Iteration No: 701
# Iteration No: 702
# Iteration No: 703
# Iteration No: 704
# Iteration No: 705
# Iteration No: 706
# Iteration No: 707
# Iteration No: 708
# Iteration No: 709
# Iteration No: 710
# We predicted a q value of  0.0
# Iteration No: 711
# Iteration No: 712
# Iteration No: 713
# Iteration No: 714
# Iteration No: 715
# Iteration No: 716
# Iteration No: 717
# Iteration No: 718
# Iteration No: 719
# Iteration No: 720
# We predicted a q value of  0.0
# Iteration No: 721
# Iteration No: 722
# Iteration No: 723
# Iteration No: 724
# Iteration No: 725
# Iteration No: 726
# Iteration No: 727
# Iteration No: 728
# Iteration No: 729
# Iteration No: 730
# We predicted a q value of  0.0
# Iteration No: 731
# Iteration No: 732
# Iteration No: 733
# Iteration No: 734
# Iteration No: 735
# Iteration No: 736
# Iteration No: 737
# Iteration No: 738
# Iteration No: 739
# Iteration No: 740
# We predicted a q value of  4.275073
# Iteration No: 741
# Iteration No: 742
# Iteration No: 743
# Iteration No: 744
# Iteration No: 745
# Iteration No: 746
# Iteration No: 747
# Iteration No: 748
# Iteration No: 749
# Iteration No: 750
# We predicted a q value of  0.0
# Iteration No: 751
# Iteration No: 752
# Iteration No: 753
# Iteration No: 754
# Iteration No: 755
# Iteration No: 756
# Iteration No: 757
# Iteration No: 758
# Iteration No: 759
# Iteration No: 760
# We predicted a q value of  4.275073
# Iteration No: 761
# Iteration No: 762
# Iteration No: 763
# Iteration No: 764
# Iteration No: 765
# Iteration No: 766
# Iteration No: 767
# Iteration No: 768
# Iteration No: 769
# Iteration No: 770
# We predicted a q value of  0.0
# Iteration No: 771
# Iteration No: 772
# Iteration No: 773
# Iteration No: 774
# Iteration No: 775
# Iteration No: 776
# Iteration No: 777
# Iteration No: 778
# Iteration No: 779
# Iteration No: 780
# We predicted a q value of  4.275073
# Iteration No: 781
# Iteration No: 782
# Iteration No: 783
# Iteration No: 784
# Iteration No: 785
# Iteration No: 786
# Iteration No: 787
# Iteration No: 788
# Iteration No: 789
# Iteration No: 790
# We predicted a q value of  4.275073
# Iteration No: 791
# Iteration No: 792
# Iteration No: 793
# Iteration No: 794
# Iteration No: 795
# Iteration No: 796
# Iteration No: 797
# Iteration No: 798
# Iteration No: 799
# Iteration No: 800
# We predicted a q value of  0.0
# Iteration No: 801
# Iteration No: 802
# Iteration No: 803
# Iteration No: 804
# Iteration No: 805
# Iteration No: 806
# Iteration No: 807
# Iteration No: 808
# Iteration No: 809
# Iteration No: 810
# We predicted a q value of  0.0
# Iteration No: 811
# Iteration No: 812
# Iteration No: 813
# Iteration No: 814
# Iteration No: 815
# Iteration No: 816
# Iteration No: 817
# Iteration No: 818
# Iteration No: 819
# Iteration No: 820
# We predicted a q value of  0.0
# Iteration No: 821
# Iteration No: 822
# Iteration No: 823
# Iteration No: 824
# Iteration No: 825
# Iteration No: 826
# Iteration No: 827
# Iteration No: 828
# Iteration No: 829
# Iteration No: 830
# We predicted a q value of  4.275073
# Iteration No: 831
# Iteration No: 832
# Iteration No: 833
# Iteration No: 834
# Iteration No: 835
# Iteration No: 836
# Iteration No: 837
# Iteration No: 838
# Iteration No: 839
# Iteration No: 840
# We predicted a q value of  4.275073
# Iteration No: 841
# Iteration No: 842
# Iteration No: 843
# Iteration No: 844
# Iteration No: 845
# Iteration No: 846
# Iteration No: 847
# Iteration No: 848
# Iteration No: 849
# Iteration No: 850
# We predicted a q value of  4.275073
# Iteration No: 851
# Iteration No: 852
# Iteration No: 853
# Iteration No: 854
# Iteration No: 855
# Iteration No: 856
# Iteration No: 857
# Iteration No: 858
# Iteration No: 859
# Iteration No: 860
# We predicted a q value of  0.0
# Iteration No: 861
# Iteration No: 862
# Iteration No: 863
# Iteration No: 864
# Iteration No: 865
# Iteration No: 866
# Iteration No: 867
# Iteration No: 868
# Iteration No: 869
# Iteration No: 870
# We predicted a q value of  4.275073
# Iteration No: 871
# Iteration No: 872
# Iteration No: 873
# Iteration No: 874
# Iteration No: 875
# Iteration No: 876
# Iteration No: 877
# Iteration No: 878
# Iteration No: 879
# Iteration No: 880
# We predicted a q value of  0.0
# Iteration No: 881
# Iteration No: 882
# Iteration No: 883
# Iteration No: 884
# Iteration No: 885
# Iteration No: 886
# Iteration No: 887
# Iteration No: 888
# Iteration No: 889
# Iteration No: 890
# We predicted a q value of  0.0
# Iteration No: 891
# Iteration No: 892
# Iteration No: 893
# Iteration No: 894
# Iteration No: 895
# Iteration No: 896
# Iteration No: 897
# Iteration No: 898
# Iteration No: 899
# Iteration No: 900
# We predicted a q value of  0.0
# Iteration No: 901
# Iteration No: 902
# Iteration No: 903
# Iteration No: 904
# Iteration No: 905
# Iteration No: 906
# Iteration No: 907
# Iteration No: 908
# Iteration No: 909
# Iteration No: 910
# We predicted a q value of  4.275073
# Iteration No: 911
# Iteration No: 912
# Iteration No: 913
# Iteration No: 914
# Iteration No: 915
# Iteration No: 916
# Iteration No: 917
# Iteration No: 918
# Iteration No: 919
# Iteration No: 920
# We predicted a q value of  0.0
# Iteration No: 921
# Iteration No: 922
# Iteration No: 923
# Iteration No: 924
# Iteration No: 925
# Iteration No: 926
# Iteration No: 927
# Iteration No: 928
# Iteration No: 929
# Iteration No: 930
# We predicted a q value of  4.275073
# Iteration No: 931
# Iteration No: 932
# Iteration No: 933
# Iteration No: 934
# Iteration No: 935
# Iteration No: 936
# Iteration No: 937
# Iteration No: 938
# Iteration No: 939
# Iteration No: 940
# We predicted a q value of  0.0
# Iteration No: 941
# Iteration No: 942
# Iteration No: 943
# Iteration No: 944
# Iteration No: 945
# Iteration No: 946
# Iteration No: 947
# Iteration No: 948
# Iteration No: 949
# Iteration No: 950
# We predicted a q value of  0.0
# Iteration No: 951
# Iteration No: 952
# Iteration No: 953
# Iteration No: 954
# Iteration No: 955
# Iteration No: 956
# Iteration No: 957
# Iteration No: 958
# Iteration No: 959
# Iteration No: 960
# We predicted a q value of  0.0
# Iteration No: 961
# Iteration No: 962
# Iteration No: 963
# Iteration No: 964
# Iteration No: 965
# Iteration No: 966
# Iteration No: 967
# Iteration No: 968
# Iteration No: 969
# Iteration No: 970
# We predicted a q value of  0.0
# Iteration No: 971
# Iteration No: 972
# Iteration No: 973
# Iteration No: 974
# Iteration No: 975
# Iteration No: 976
# Iteration No: 977
# Iteration No: 978
# Iteration No: 979
# Iteration No: 980
# We predicted a q value of  4.275073
# Iteration No: 981
# Iteration No: 982
# Iteration No: 983
# Iteration No: 984
# Iteration No: 985
# Iteration No: 986
# Iteration No: 987
# Iteration No: 988
# Iteration No: 989
# Iteration No: 990
# We predicted a q value of  0.0
# Iteration No: 991
# Iteration No: 992
# Iteration No: 993
# Iteration No: 994
# Iteration No: 995
# Iteration No: 996
# Iteration No: 997
# Iteration No: 998
# Iteration No: 999
# Executing loop 999
# Iteration No: 1000
# We predicted a q value of  4.275073
# Iteration No: 1001
# Iteration No: 1002
# Iteration No: 1003
# Iteration No: 1004
# Iteration No: 1005
# Iteration No: 1006
# Iteration No: 1007
# Iteration No: 1008
# Iteration No: 1009
# Iteration No: 1010
# We predicted a q value of  4.275073
# Iteration No: 1011
# Iteration No: 1012
# Iteration No: 1013
# Iteration No: 1014
# Iteration No: 1015
# Iteration No: 1016
# Iteration No: 1017
# Iteration No: 1018
# Iteration No: 1019
# Iteration No: 1020
# We predicted a q value of  4.275073
# Iteration No: 1021
# Iteration No: 1022
# Iteration No: 1023
# Iteration No: 1024
# Iteration No: 1025
# Iteration No: 1026
# Iteration No: 1027
# Iteration No: 1028
# Iteration No: 1029
# Iteration No: 1030
# We predicted a q value of  0.0
# Iteration No: 1031
# Iteration No: 1032
# Iteration No: 1033
# Iteration No: 1034
# Iteration No: 1035
# Iteration No: 1036
# Iteration No: 1037
# Iteration No: 1038
# Iteration No: 1039
# Iteration No: 1040
# We predicted a q value of  4.275073
# Iteration No: 1041
# Iteration No: 1042
# Iteration No: 1043
# Iteration No: 1044
# Iteration No: 1045
# Iteration No: 1046
# Iteration No: 1047
# Iteration No: 1048
# Iteration No: 1049
# Iteration No: 1050
# We predicted a q value of  4.275073
# Iteration No: 1051
# Iteration No: 1052
# Iteration No: 1053
# Iteration No: 1054
# Iteration No: 1055
# Iteration No: 1056
# Iteration No: 1057
# Iteration No: 1058
# Iteration No: 1059
# Iteration No: 1060
# We predicted a q value of  0.0
# Iteration No: 1061
# Iteration No: 1062
# Iteration No: 1063
# Iteration No: 1064
# Iteration No: 1065
# Iteration No: 1066
# Iteration No: 1067
# Iteration No: 1068
# Iteration No: 1069
# Iteration No: 1070
# We predicted a q value of  4.275073
# Iteration No: 1071
# Iteration No: 1072
# Iteration No: 1073
# Iteration No: 1074
# Iteration No: 1075
# Iteration No: 1076
# Iteration No: 1077
# Iteration No: 1078
# Iteration No: 1079
# Iteration No: 1080
# We predicted a q value of  0.0
# Iteration No: 1081
# Iteration No: 1082
# Iteration No: 1083
# Iteration No: 1084
# Iteration No: 1085
# Iteration No: 1086
# Iteration No: 1087
# Iteration No: 1088
# Iteration No: 1089
# Iteration No: 1090
# We predicted a q value of  0.0
# Iteration No: 1091
# Iteration No: 1092
# Iteration No: 1093
# Iteration No: 1094
# Iteration No: 1095
# Iteration No: 1096
# Iteration No: 1097
# Iteration No: 1098
# Iteration No: 1099
# Iteration No: 1100
# We predicted a q value of  4.275073
# Iteration No: 1101
# Iteration No: 1102
# Iteration No: 1103
# Iteration No: 1104
# Iteration No: 1105
# Iteration No: 1106
# Lived with maximum time  443
# Earned a total of reward equal to  305.0
# Iteration No: 1107
# Iteration No: 1108
# Iteration No: 1109
# Iteration No: 1110
# We predicted a q value of  0.0
# Iteration No: 1111
# Iteration No: 1112
# Iteration No: 1113
# Iteration No: 1114
# Iteration No: 1115
# Iteration No: 1116
# Iteration No: 1117
# Iteration No: 1118
# Iteration No: 1119
# Iteration No: 1120
# We predicted a q value of  0.0
# Iteration No: 1121
# Iteration No: 1122
# Iteration No: 1123
# Iteration No: 1124
# Iteration No: 1125
# Iteration No: 1126
# Iteration No: 1127
# Iteration No: 1128
# Iteration No: 1129
# Iteration No: 1130
# We predicted a q value of  0.0
# Iteration No: 1131
# Iteration No: 1132
# Iteration No: 1133
# Iteration No: 1134
# Iteration No: 1135
# Iteration No: 1136
# Iteration No: 1137
# Iteration No: 1138
# Iteration No: 1139
# Iteration No: 1140
# We predicted a q value of  0.0
# Iteration No: 1141
# Iteration No: 1142
# Iteration No: 1143
# Iteration No: 1144
# Iteration No: 1145
# Iteration No: 1146
# Iteration No: 1147
# Iteration No: 1148
# Iteration No: 1149
# Iteration No: 1150
# We predicted a q value of  0.0
# Iteration No: 1151
# Iteration No: 1152
# Iteration No: 1153
# Iteration No: 1154
# Iteration No: 1155
# Iteration No: 1156
# Iteration No: 1157
# Iteration No: 1158
# Iteration No: 1159
# Iteration No: 1160
# We predicted a q value of  0.0
# Iteration No: 1161
# Iteration No: 1162
# Iteration No: 1163
# Iteration No: 1164
# Iteration No: 1165
# Iteration No: 1166
# Iteration No: 1167
# Iteration No: 1168
# Iteration No: 1169
# Iteration No: 1170
# We predicted a q value of  4.275073
# Iteration No: 1171
# Iteration No: 1172
# Iteration No: 1173
# Iteration No: 1174
# Iteration No: 1175
# Iteration No: 1176
# Iteration No: 1177
# Iteration No: 1178
# Iteration No: 1179
# Iteration No: 1180
# We predicted a q value of  0.0
# Iteration No: 1181
# Iteration No: 1182
# Iteration No: 1183
# Iteration No: 1184
# Iteration No: 1185
# Iteration No: 1186
# Iteration No: 1187
# Iteration No: 1188
# Iteration No: 1189
# Iteration No: 1190
# We predicted a q value of  0.0
# Iteration No: 1191
# Iteration No: 1192
# Iteration No: 1193
# Iteration No: 1194
# Iteration No: 1195
# Iteration No: 1196
# Iteration No: 1197
# Iteration No: 1198
# Iteration No: 1199
# Iteration No: 1200
# We predicted a q value of  4.275073
# Iteration No: 1201
# Iteration No: 1202
# Iteration No: 1203
# Iteration No: 1204
# Iteration No: 1205
# Iteration No: 1206
# Iteration No: 1207
# Iteration No: 1208
# Iteration No: 1209
# Iteration No: 1210
# We predicted a q value of  4.275073
# Iteration No: 1211
# Iteration No: 1212
# Iteration No: 1213
# Iteration No: 1214
# Iteration No: 1215
# Iteration No: 1216
# Iteration No: 1217
# Iteration No: 1218
# Iteration No: 1219
# Iteration No: 1220
# We predicted a q value of  4.275073
# Iteration No: 1221
# Iteration No: 1222
# Iteration No: 1223
# Iteration No: 1224
# Iteration No: 1225
# Iteration No: 1226
# Iteration No: 1227
# Iteration No: 1228
# Iteration No: 1229
# Iteration No: 1230
# We predicted a q value of  0.0
# Iteration No: 1231
# Iteration No: 1232
# Iteration No: 1233
# Iteration No: 1234
# Iteration No: 1235
# Iteration No: 1236
# Iteration No: 1237
# Iteration No: 1238
# Iteration No: 1239
# Iteration No: 1240
# We predicted a q value of  0.0
# Iteration No: 1241
# Iteration No: 1242
# Iteration No: 1243
# Iteration No: 1244
# Iteration No: 1245
# Iteration No: 1246
# Iteration No: 1247
# Iteration No: 1248
# Iteration No: 1249
# Iteration No: 1250
# We predicted a q value of  4.275073
# Iteration No: 1251
# Iteration No: 1252
# Iteration No: 1253
# Iteration No: 1254
# Iteration No: 1255
# Iteration No: 1256
# Iteration No: 1257
# Iteration No: 1258
# Iteration No: 1259
# Iteration No: 1260
# We predicted a q value of  0.0
# Iteration No: 1261
# Iteration No: 1262
# Iteration No: 1263
# Iteration No: 1264
# Iteration No: 1265
# Iteration No: 1266
# Iteration No: 1267
# Iteration No: 1268
# Iteration No: 1269
# Iteration No: 1270
# We predicted a q value of  4.275073
# Iteration No: 1271
# Iteration No: 1272
# Iteration No: 1273
# Iteration No: 1274
# Iteration No: 1275
# Iteration No: 1276
# Iteration No: 1277
# Iteration No: 1278
# Iteration No: 1279
# Iteration No: 1280
# We predicted a q value of  4.275073
# Iteration No: 1281
# Iteration No: 1282
# Iteration No: 1283
# Iteration No: 1284
# Iteration No: 1285
# Iteration No: 1286
# Iteration No: 1287
# Iteration No: 1288
# Iteration No: 1289
# Iteration No: 1290
# We predicted a q value of  0.0
# Iteration No: 1291
# Iteration No: 1292
# Iteration No: 1293
# Iteration No: 1294
# Iteration No: 1295
# Iteration No: 1296
# Iteration No: 1297
# Iteration No: 1298
# Iteration No: 1299
# Iteration No: 1300
# We predicted a q value of  0.0
# Iteration No: 1301
# Iteration No: 1302
# Iteration No: 1303
# Iteration No: 1304
# Iteration No: 1305
# Iteration No: 1306
# Iteration No: 1307
# Iteration No: 1308
# Iteration No: 1309
# Iteration No: 1310
# We predicted a q value of  0.0
# Iteration No: 1311
# Iteration No: 1312
# Iteration No: 1313
# Iteration No: 1314
# Iteration No: 1315
# Iteration No: 1316
# Iteration No: 1317
# Iteration No: 1318
# Iteration No: 1319
# Iteration No: 1320
# We predicted a q value of  0.0
# Iteration No: 1321
# Iteration No: 1322
# Iteration No: 1323
# Iteration No: 1324
# Iteration No: 1325
# Iteration No: 1326
# Iteration No: 1327
# Iteration No: 1328
# Iteration No: 1329
# Iteration No: 1330
# We predicted a q value of  4.275073
# Iteration No: 1331
# Iteration No: 1332
# Iteration No: 1333
# Iteration No: 1334
# Iteration No: 1335
# Iteration No: 1336
# Iteration No: 1337
# Iteration No: 1338
# Iteration No: 1339
# Iteration No: 1340
# We predicted a q value of  4.275073
# Iteration No: 1341
# Iteration No: 1342
# Iteration No: 1343
# Iteration No: 1344
# Iteration No: 1345
# Iteration No: 1346
# Iteration No: 1347
# Iteration No: 1348
# Iteration No: 1349
# Iteration No: 1350
# We predicted a q value of  4.275073
# Iteration No: 1351
# Iteration No: 1352
# Iteration No: 1353
# Iteration No: 1354
# Iteration No: 1355
# Iteration No: 1356
# Iteration No: 1357
# Iteration No: 1358
# Iteration No: 1359
# Iteration No: 1360
# We predicted a q value of  0.0
# Iteration No: 1361
# Iteration No: 1362
# Iteration No: 1363
# Iteration No: 1364
# Iteration No: 1365
# Iteration No: 1366
# Iteration No: 1367
# Iteration No: 1368
# Iteration No: 1369
# Iteration No: 1370
# We predicted a q value of  0.0
# Iteration No: 1371
# Iteration No: 1372
# Iteration No: 1373
# Iteration No: 1374
# Lived with maximum time  268
# Earned a total of reward equal to  185.0
# Iteration No: 1375
# Iteration No: 1376
# Iteration No: 1377
# Iteration No: 1378
# Iteration No: 1379
# Iteration No: 1380
# We predicted a q value of  0.0
# Iteration No: 1381
# Iteration No: 1382
# Iteration No: 1383
# Iteration No: 1384
# Iteration No: 1385
# Iteration No: 1386
# Iteration No: 1387
# Iteration No: 1388
# Iteration No: 1389
# Iteration No: 1390
# We predicted a q value of  0.0
# Iteration No: 1391
# Iteration No: 1392
# Iteration No: 1393
# Iteration No: 1394
# Iteration No: 1395
# Iteration No: 1396
# Iteration No: 1397
# Iteration No: 1398
# Iteration No: 1399
# Iteration No: 1400
# We predicted a q value of  0.0
# Iteration No: 1401
# Iteration No: 1402
# Iteration No: 1403
# Iteration No: 1404
# Iteration No: 1405
# Iteration No: 1406
# Iteration No: 1407
# Iteration No: 1408
# Iteration No: 1409
# Iteration No: 1410
# We predicted a q value of  0.0
# Iteration No: 1411
# Iteration No: 1412
# Iteration No: 1413
# Iteration No: 1414
# Iteration No: 1415
# Iteration No: 1416
# Iteration No: 1417
# Iteration No: 1418
# Iteration No: 1419
# Iteration No: 1420
# We predicted a q value of  4.275073
# Iteration No: 1421
# Iteration No: 1422
# Iteration No: 1423
# Iteration No: 1424
# Iteration No: 1425
# Iteration No: 1426
# Iteration No: 1427
# Iteration No: 1428
# Iteration No: 1429
# Iteration No: 1430
# We predicted a q value of  4.275073
# Iteration No: 1431
# Iteration No: 1432
# Iteration No: 1433
# Iteration No: 1434
# Iteration No: 1435
# Iteration No: 1436
# Iteration No: 1437
# Iteration No: 1438
# Iteration No: 1439
# Iteration No: 1440
# We predicted a q value of  4.275073
# Iteration No: 1441
# Iteration No: 1442
# Iteration No: 1443
# Iteration No: 1444
# Iteration No: 1445
# Iteration No: 1446
# Iteration No: 1447
# Iteration No: 1448
# Iteration No: 1449
# Iteration No: 1450
# We predicted a q value of  0.0
# Iteration No: 1451
# Iteration No: 1452
# Iteration No: 1453
# Iteration No: 1454
# Iteration No: 1455
# Iteration No: 1456
# Iteration No: 1457
# Iteration No: 1458
# Iteration No: 1459
# Iteration No: 1460
# We predicted a q value of  4.275073
# Iteration No: 1461
# Iteration No: 1462
# Iteration No: 1463
# Iteration No: 1464
# Iteration No: 1465
# Iteration No: 1466
# Iteration No: 1467
# Iteration No: 1468
# Iteration No: 1469
# Iteration No: 1470
# We predicted a q value of  4.275073
# Iteration No: 1471
# Iteration No: 1472
# Iteration No: 1473
# Iteration No: 1474
# Iteration No: 1475
# Iteration No: 1476
# Iteration No: 1477
# Iteration No: 1478
# Iteration No: 1479
# Iteration No: 1480
# We predicted a q value of  4.275073
# Iteration No: 1481
# Iteration No: 1482
# Iteration No: 1483
# Iteration No: 1484
# Iteration No: 1485
# Iteration No: 1486
# Iteration No: 1487
# Iteration No: 1488
# Iteration No: 1489
# Iteration No: 1490
# We predicted a q value of  4.275073
# Iteration No: 1491
# Iteration No: 1492
# Iteration No: 1493
# Iteration No: 1494
# Iteration No: 1495
# Iteration No: 1496
# Iteration No: 1497
# Iteration No: 1498
# Iteration No: 1499
# Iteration No: 1500
# We predicted a q value of  4.275073
# Iteration No: 1501
# Iteration No: 1502
# Iteration No: 1503
# Iteration No: 1504
# Iteration No: 1505
# Iteration No: 1506
# Iteration No: 1507
# Iteration No: 1508
# Iteration No: 1509
# Iteration No: 1510
# We predicted a q value of  0.0
# Iteration No: 1511
# Iteration No: 1512
# Iteration No: 1513
# Iteration No: 1514
# Iteration No: 1515
# Iteration No: 1516
# Iteration No: 1517
# Iteration No: 1518
# Iteration No: 1519
# Iteration No: 1520
# We predicted a q value of  0.0
# Iteration No: 1521
# Iteration No: 1522
# Iteration No: 1523
# Iteration No: 1524
# Iteration No: 1525
# Iteration No: 1526
# Iteration No: 1527
# Iteration No: 1528
# Iteration No: 1529
# Iteration No: 1530
# We predicted a q value of  0.0
# Iteration No: 1531
# Iteration No: 1532
# Iteration No: 1533
# Iteration No: 1534
# Iteration No: 1535
# Iteration No: 1536
# Iteration No: 1537
# Iteration No: 1538
# Iteration No: 1539
# Iteration No: 1540
# We predicted a q value of  0.0
# Iteration No: 1541
# Iteration No: 1542
# Iteration No: 1543
# Iteration No: 1544
# Iteration No: 1545
# Iteration No: 1546
# Iteration No: 1547
# Iteration No: 1548
# Iteration No: 1549
# Iteration No: 1550
# We predicted a q value of  0.0
# Iteration No: 1551
# Iteration No: 1552
# Iteration No: 1553
# Iteration No: 1554
# Iteration No: 1555
# Iteration No: 1556
# Iteration No: 1557
# Iteration No: 1558
# Iteration No: 1559
# Iteration No: 1560
# We predicted a q value of  0.0
# Iteration No: 1561
# Iteration No: 1562
# Iteration No: 1563
# Iteration No: 1564
# Iteration No: 1565
# Iteration No: 1566
# Iteration No: 1567
# Iteration No: 1568
# Iteration No: 1569
# Iteration No: 1570
# We predicted a q value of  0.0
# Iteration No: 1571
# Iteration No: 1572
# Iteration No: 1573
# Iteration No: 1574
# Iteration No: 1575
# Iteration No: 1576
# Iteration No: 1577
# Iteration No: 1578
# Iteration No: 1579
# Iteration No: 1580
# We predicted a q value of  0.0
# Iteration No: 1581
# Iteration No: 1582
# Iteration No: 1583
# Iteration No: 1584
# Iteration No: 1585
# Iteration No: 1586
# Iteration No: 1587
# Iteration No: 1588
# Iteration No: 1589
# Iteration No: 1590
# We predicted a q value of  0.0
# Iteration No: 1591
# Iteration No: 1592
# Iteration No: 1593
# Iteration No: 1594
# Iteration No: 1595
# Iteration No: 1596
# Iteration No: 1597
# Iteration No: 1598
# Iteration No: 1599
# Iteration No: 1600
# We predicted a q value of  4.275073
# Iteration No: 1601
# Iteration No: 1602
# Iteration No: 1603
# Iteration No: 1604
# Iteration No: 1605
# Iteration No: 1606
# Iteration No: 1607
# Iteration No: 1608
# Iteration No: 1609
# Iteration No: 1610
# We predicted a q value of  0.0
# Iteration No: 1611
# Iteration No: 1612
# Iteration No: 1613
# Iteration No: 1614
# Iteration No: 1615
# Iteration No: 1616
# Iteration No: 1617
# Iteration No: 1618
# Iteration No: 1619
# Iteration No: 1620
# We predicted a q value of  0.0
# Iteration No: 1621
# Iteration No: 1622
# Iteration No: 1623
# Iteration No: 1624
# Iteration No: 1625
# Iteration No: 1626
# Iteration No: 1627
# Iteration No: 1628
# Lived with maximum time  254
# Earned a total of reward equal to  120.0
# Iteration No: 1629
# Iteration No: 1630
# We predicted a q value of  4.275073
# Iteration No: 1631
# Iteration No: 1632
# Iteration No: 1633
# Iteration No: 1634
# Iteration No: 1635
# Iteration No: 1636
# Iteration No: 1637
# Iteration No: 1638
# Iteration No: 1639
# Iteration No: 1640
# We predicted a q value of  4.275073
# Iteration No: 1641
# Iteration No: 1642
# Iteration No: 1643
# Iteration No: 1644
# Iteration No: 1645
# Iteration No: 1646
# Iteration No: 1647
# Iteration No: 1648
# Iteration No: 1649
# Iteration No: 1650
# We predicted a q value of  0.0
# Iteration No: 1651
# Iteration No: 1652
# Iteration No: 1653
# Iteration No: 1654
# Iteration No: 1655
# Iteration No: 1656
# Iteration No: 1657
# Iteration No: 1658
# Iteration No: 1659
# Iteration No: 1660
# We predicted a q value of  4.275073
# Iteration No: 1661
# Iteration No: 1662
# Iteration No: 1663
# Iteration No: 1664
# Iteration No: 1665
# Iteration No: 1666
# Iteration No: 1667
# Iteration No: 1668
# Iteration No: 1669
# Iteration No: 1670
# We predicted a q value of  4.275073
# Iteration No: 1671
# Iteration No: 1672
# Iteration No: 1673
# Iteration No: 1674
# Iteration No: 1675
# Iteration No: 1676
# Iteration No: 1677
# Iteration No: 1678
# Iteration No: 1679
# Iteration No: 1680
# We predicted a q value of  0.0
# Iteration No: 1681
# Iteration No: 1682
# Iteration No: 1683
# Iteration No: 1684
# Iteration No: 1685
# Iteration No: 1686
# Iteration No: 1687
# Iteration No: 1688
# Iteration No: 1689
# Iteration No: 1690
# We predicted a q value of  0.0
# Iteration No: 1691
# Iteration No: 1692
# Iteration No: 1693
# Iteration No: 1694
# Iteration No: 1695
# Iteration No: 1696
# Iteration No: 1697
# Iteration No: 1698
# Iteration No: 1699
# Iteration No: 1700
# We predicted a q value of  0.0
# Iteration No: 1701
# Iteration No: 1702
# Iteration No: 1703
# Iteration No: 1704
# Iteration No: 1705
# Iteration No: 1706
# Iteration No: 1707
# Iteration No: 1708
# Iteration No: 1709
# Iteration No: 1710
# We predicted a q value of  0.0
# Iteration No: 1711
# Iteration No: 1712
# Iteration No: 1713
# Iteration No: 1714
# Iteration No: 1715
# Iteration No: 1716
# Iteration No: 1717
# Iteration No: 1718
# Iteration No: 1719
# Iteration No: 1720
# We predicted a q value of  4.275073
# Iteration No: 1721
# Iteration No: 1722
# Iteration No: 1723
# Iteration No: 1724
# Iteration No: 1725
# Iteration No: 1726
# Iteration No: 1727
# Iteration No: 1728
# Iteration No: 1729
# Iteration No: 1730
# We predicted a q value of  4.275073
# Iteration No: 1731
# Iteration No: 1732
# Iteration No: 1733
# Iteration No: 1734
# Iteration No: 1735
# Iteration No: 1736
# Iteration No: 1737
# Iteration No: 1738
# Iteration No: 1739
# Iteration No: 1740
# We predicted a q value of  0.0
# Iteration No: 1741
# Iteration No: 1742
# Iteration No: 1743
# Iteration No: 1744
# Iteration No: 1745
# Iteration No: 1746
# Iteration No: 1747
# Iteration No: 1748
# Iteration No: 1749
# Iteration No: 1750
# We predicted a q value of  0.0
# Iteration No: 1751
# Iteration No: 1752
# Iteration No: 1753
# Iteration No: 1754
# Iteration No: 1755
# Iteration No: 1756
# Iteration No: 1757
# Iteration No: 1758
# Iteration No: 1759
# Iteration No: 1760
# We predicted a q value of  0.0
# Iteration No: 1761
# Iteration No: 1762
# Iteration No: 1763
# Iteration No: 1764
# Iteration No: 1765
# Iteration No: 1766
# Iteration No: 1767
# Iteration No: 1768
# Iteration No: 1769
# Iteration No: 1770
# We predicted a q value of  4.275073
# Iteration No: 1771
# Iteration No: 1772
# Iteration No: 1773
# Iteration No: 1774
# Iteration No: 1775
# Iteration No: 1776
# Iteration No: 1777
# Iteration No: 1778
# Iteration No: 1779
# Iteration No: 1780
# We predicted a q value of  0.0
# Iteration No: 1781
# Iteration No: 1782
# Iteration No: 1783
# Iteration No: 1784
# Iteration No: 1785
# Iteration No: 1786
# Iteration No: 1787
# Iteration No: 1788
# Iteration No: 1789
# Iteration No: 1790
# We predicted a q value of  0.0
# Iteration No: 1791
# Lived with maximum time  163
# Earned a total of reward equal to  20.0
# Iteration No: 1792
# Iteration No: 1793
# Iteration No: 1794
# Iteration No: 1795
# Iteration No: 1796
# Iteration No: 1797
# Iteration No: 1798
# Iteration No: 1799
# Iteration No: 1800
# We predicted a q value of  0.0
# Iteration No: 1801
# Iteration No: 1802
# Iteration No: 1803
# Iteration No: 1804
# Iteration No: 1805
# Iteration No: 1806
# Iteration No: 1807
# Iteration No: 1808
# Iteration No: 1809
# Iteration No: 1810
# We predicted a q value of  4.275073
# Iteration No: 1811
# Iteration No: 1812
# Iteration No: 1813
# Iteration No: 1814
# Iteration No: 1815
# Iteration No: 1816
# Iteration No: 1817
# Iteration No: 1818
# Iteration No: 1819
# Iteration No: 1820
# We predicted a q value of  4.275073
# Iteration No: 1821
# Iteration No: 1822
# Iteration No: 1823
# Iteration No: 1824
# Iteration No: 1825
# Iteration No: 1826
# Iteration No: 1827
# Iteration No: 1828
# Iteration No: 1829
# Iteration No: 1830
# We predicted a q value of  0.0
# Iteration No: 1831
# Iteration No: 1832
# Iteration No: 1833
# Iteration No: 1834
# Iteration No: 1835
# Iteration No: 1836
# Iteration No: 1837
# Iteration No: 1838
# Iteration No: 1839
# Iteration No: 1840
# We predicted a q value of  0.0
# Iteration No: 1841
# Iteration No: 1842
# Iteration No: 1843
# Iteration No: 1844
# Iteration No: 1845
# Iteration No: 1846
# Iteration No: 1847
# Iteration No: 1848
# Iteration No: 1849
# Iteration No: 1850
# We predicted a q value of  0.0
# Iteration No: 1851
# Iteration No: 1852
# Iteration No: 1853
# Iteration No: 1854
# Iteration No: 1855
# Iteration No: 1856
# Iteration No: 1857
# Iteration No: 1858
# Iteration No: 1859
# Iteration No: 1860
# We predicted a q value of  4.275073
# Iteration No: 1861
# Iteration No: 1862
# Iteration No: 1863
# Iteration No: 1864
# Iteration No: 1865
# Iteration No: 1866
# Iteration No: 1867
# Iteration No: 1868
# Iteration No: 1869
# Iteration No: 1870
# We predicted a q value of  0.0
# Iteration No: 1871
# Iteration No: 1872
# Iteration No: 1873
# Iteration No: 1874
# Iteration No: 1875
# Iteration No: 1876
# Iteration No: 1877
# Iteration No: 1878
# Iteration No: 1879
# Iteration No: 1880
# We predicted a q value of  4.275073
# Iteration No: 1881
# Iteration No: 1882
# Iteration No: 1883
# Iteration No: 1884
# Iteration No: 1885
# Iteration No: 1886
# Iteration No: 1887
# Iteration No: 1888
# Iteration No: 1889
# Iteration No: 1890
# We predicted a q value of  0.0
# Iteration No: 1891
# Iteration No: 1892
# Iteration No: 1893
# Iteration No: 1894
# Iteration No: 1895
# Iteration No: 1896
# Iteration No: 1897
# Iteration No: 1898
# Iteration No: 1899
# Iteration No: 1900
# We predicted a q value of  0.0
# Iteration No: 1901
# Iteration No: 1902
# Iteration No: 1903
# Iteration No: 1904
# Iteration No: 1905
# Iteration No: 1906
# Iteration No: 1907
# Iteration No: 1908
# Iteration No: 1909
# Iteration No: 1910
# We predicted a q value of  0.0
# Iteration No: 1911
# Iteration No: 1912
# Iteration No: 1913
# Iteration No: 1914
# Iteration No: 1915
# Iteration No: 1916
# Iteration No: 1917
# Iteration No: 1918
# Iteration No: 1919
# Iteration No: 1920
# We predicted a q value of  0.0
# Iteration No: 1921
# Iteration No: 1922
# Iteration No: 1923
# Iteration No: 1924
# Iteration No: 1925
# Iteration No: 1926
# Iteration No: 1927
# Iteration No: 1928
# Iteration No: 1929
# Iteration No: 1930
# We predicted a q value of  0.0
# Iteration No: 1931
# Iteration No: 1932
# Iteration No: 1933
# Iteration No: 1934
# Lived with maximum time  143
# Earned a total of reward equal to  50.0
# Iteration No: 1935
# Iteration No: 1936
# Iteration No: 1937
# Iteration No: 1938
# Iteration No: 1939
# Iteration No: 1940
# We predicted a q value of  4.275073
# Iteration No: 1941
# Iteration No: 1942
# Iteration No: 1943
# Iteration No: 1944
# Iteration No: 1945
# Iteration No: 1946
# Iteration No: 1947
# Iteration No: 1948
# Iteration No: 1949
# Iteration No: 1950
# We predicted a q value of  4.275073
# Iteration No: 1951
# Iteration No: 1952
# Iteration No: 1953
# Iteration No: 1954
# Iteration No: 1955
# Iteration No: 1956
# Iteration No: 1957
# Iteration No: 1958
# Iteration No: 1959
# Iteration No: 1960
# We predicted a q value of  0.0
# Iteration No: 1961
# Iteration No: 1962
# Iteration No: 1963
# Iteration No: 1964
# Iteration No: 1965
# Iteration No: 1966
# Iteration No: 1967
# Iteration No: 1968
# Iteration No: 1969
# Iteration No: 1970
# We predicted a q value of  0.0
# Iteration No: 1971
# Iteration No: 1972
# Iteration No: 1973
# Iteration No: 1974
# Iteration No: 1975
# Iteration No: 1976
# Iteration No: 1977
# Iteration No: 1978
# Iteration No: 1979
# Iteration No: 1980
# We predicted a q value of  4.275073
# Iteration No: 1981
# Iteration No: 1982
# Iteration No: 1983
# Iteration No: 1984
# Iteration No: 1985
# Iteration No: 1986
# Iteration No: 1987
# Iteration No: 1988
# Iteration No: 1989
# Iteration No: 1990
# We predicted a q value of  0.0
# Iteration No: 1991
# Iteration No: 1992
# Iteration No: 1993
# Iteration No: 1994
# Iteration No: 1995
# Iteration No: 1996
# Iteration No: 1997
# Iteration No: 1998
# Iteration No: 1999
# Executing loop 1999
# Iteration No: 2000
# We predicted a q value of  4.275073
# Iteration No: 2001
# Iteration No: 2002
# Iteration No: 2003
# Iteration No: 2004
# Iteration No: 2005
# Iteration No: 2006
# Iteration No: 2007
# Iteration No: 2008
# Iteration No: 2009
# Iteration No: 2010
# We predicted a q value of  0.0
# Iteration No: 2011
# Iteration No: 2012
# Iteration No: 2013
# Iteration No: 2014
# Iteration No: 2015
# Iteration No: 2016
# Iteration No: 2017
# Iteration No: 2018
# Iteration No: 2019
# Iteration No: 2020
# We predicted a q value of  4.275073
# Iteration No: 2021
# Iteration No: 2022
# Iteration No: 2023
# Iteration No: 2024
# Iteration No: 2025
# Iteration No: 2026
# Iteration No: 2027
# Iteration No: 2028
# Iteration No: 2029
# Iteration No: 2030
# We predicted a q value of  0.0
# Iteration No: 2031
# Iteration No: 2032
# Iteration No: 2033
# Iteration No: 2034
# Iteration No: 2035
# Iteration No: 2036
# Iteration No: 2037
# Iteration No: 2038
# Iteration No: 2039
# Iteration No: 2040
# We predicted a q value of  0.0
# Iteration No: 2041
# Iteration No: 2042
# Iteration No: 2043
# Iteration No: 2044
# Iteration No: 2045
# Iteration No: 2046
# Iteration No: 2047
# Iteration No: 2048
# Iteration No: 2049
# Iteration No: 2050
# We predicted a q value of  4.275073
# Iteration No: 2051
# Iteration No: 2052
# Iteration No: 2053
# Iteration No: 2054
# Iteration No: 2055
# Iteration No: 2056
# Iteration No: 2057
# Iteration No: 2058
# Iteration No: 2059
# Iteration No: 2060
# We predicted a q value of  0.0
# Iteration No: 2061
# Iteration No: 2062
# Iteration No: 2063
# Lived with maximum time  129
# Earned a total of reward equal to  45.0
# Iteration No: 2064
# Iteration No: 2065
# Iteration No: 2066
# Iteration No: 2067
# Iteration No: 2068
# Iteration No: 2069
# Iteration No: 2070
# We predicted a q value of  0.0
# Iteration No: 2071
# Iteration No: 2072
# Iteration No: 2073
# Iteration No: 2074
# Iteration No: 2075
# Iteration No: 2076
# Iteration No: 2077
# Iteration No: 2078
# Iteration No: 2079
# Iteration No: 2080
# We predicted a q value of  0.0
# Iteration No: 2081
# Iteration No: 2082
# Iteration No: 2083
# Iteration No: 2084
# Iteration No: 2085
# Iteration No: 2086
# Iteration No: 2087
# Iteration No: 2088
# Iteration No: 2089
# Iteration No: 2090
# We predicted a q value of  0.0
# Iteration No: 2091
# Iteration No: 2092
# Iteration No: 2093
# Iteration No: 2094
# Iteration No: 2095
# Iteration No: 2096
# Iteration No: 2097
# Iteration No: 2098
# Iteration No: 2099
# Iteration No: 2100
# We predicted a q value of  0.0
# Iteration No: 2101
# Iteration No: 2102
# Iteration No: 2103
# Iteration No: 2104
# Iteration No: 2105
# Iteration No: 2106
# Iteration No: 2107
# Iteration No: 2108
# Iteration No: 2109
# Iteration No: 2110
# We predicted a q value of  0.0
# Iteration No: 2111
# Iteration No: 2112
# Iteration No: 2113
# Iteration No: 2114
# Iteration No: 2115
# Iteration No: 2116
# Iteration No: 2117
# Iteration No: 2118
# Iteration No: 2119
# Iteration No: 2120
# We predicted a q value of  0.0
# Iteration No: 2121
# Iteration No: 2122
# Iteration No: 2123
# Iteration No: 2124
# Iteration No: 2125
# Iteration No: 2126
# Iteration No: 2127
# Iteration No: 2128
# Iteration No: 2129
# Iteration No: 2130
# We predicted a q value of  0.0
# Iteration No: 2131
# Iteration No: 2132
# Iteration No: 2133
# Iteration No: 2134
# Iteration No: 2135
# Iteration No: 2136
# Iteration No: 2137
# Iteration No: 2138
# Iteration No: 2139
# Iteration No: 2140
# We predicted a q value of  0.0
# Iteration No: 2141
# Iteration No: 2142
# Iteration No: 2143
# Iteration No: 2144
# Iteration No: 2145
# Iteration No: 2146
# Iteration No: 2147
# Iteration No: 2148
# Iteration No: 2149
# Iteration No: 2150
# We predicted a q value of  0.0
# Iteration No: 2151
# Iteration No: 2152
# Iteration No: 2153
# Iteration No: 2154
# Iteration No: 2155
# Iteration No: 2156
# Iteration No: 2157
# Iteration No: 2158
# Iteration No: 2159
# Iteration No: 2160
# We predicted a q value of  0.0
# Iteration No: 2161
# Iteration No: 2162
# Iteration No: 2163
# Iteration No: 2164
# Iteration No: 2165
# Iteration No: 2166
# Iteration No: 2167
# Iteration No: 2168
# Iteration No: 2169
# Iteration No: 2170
# We predicted a q value of  0.0
# Iteration No: 2171
# Iteration No: 2172
# ...
# Iteration No: 3393
# Iteration No: 3394
# Iteration No: 3395
# Iteration No: 3396
# Iteration No: 3397
# Iteration No: 3398
# Iteration No: 3399
# Iteration No: 3400
# We predicted a q value of  45.526455
# We had a loss equal to  67.51864
# Iteration No: 3401
# Iteration No: 3402
# Iteration No: 3403
# Iteration No: 3404
# Iteration No: 3405
# Iteration No: 3406
# Iteration No: 3407
# Iteration No: 3408
# Iteration No: 3409
# Iteration No: 3410
# We predicted a q value of  48.282177
# We had a loss equal to  72.137054
# Iteration No: 3411
# Iteration No: 3412
# Iteration No: 3413
# Iteration No: 3414
# Iteration No: 3415
# Iteration No: 3416
# Iteration No: 3417
# Iteration No: 3418
# Iteration No: 3419
# Iteration No: 3420
# We predicted a q value of  49.49185
# We had a loss equal to  40.233124
# Iteration No: 3421
# Iteration No: 3422
# Iteration No: 3423
# Iteration No: 3424
# Iteration No: 3425
# Iteration No: 3426
# Iteration No: 3427
# Iteration No: 3428
# Iteration No: 3429
# Iteration No: 3430
# We predicted a q value of  51.505325
# We had a loss equal to  42.719826
# Iteration No: 3431
# Iteration No: 3432
# Iteration No: 3433
# Iteration No: 3434
# Iteration No: 3435
# Iteration No: 3436
# Iteration No: 3437
# Iteration No: 3438
# Iteration No: 3439
# Iteration No: 3440
# We predicted a q value of  0.0
# We had a loss equal to  109.21806
# Iteration No: 3441
# Iteration No: 3442
# Iteration No: 3443
# Iteration No: 3444
# Iteration No: 3445
# Iteration No: 3446
# Iteration No: 3447
# Lived with maximum time  125
# Earned a total of reward equal to  15.0
# Iteration No: 3448
# Iteration No: 3449
# Iteration No: 3450
# We predicted a q value of  56.180912
# We had a loss equal to  118.89956
# Iteration No: 3451
# Iteration No: 3452
# Iteration No: 3453
# Iteration No: 3454
# Iteration No: 3455
# Iteration No: 3456
# Iteration No: 3457
# Iteration No: 3458
# Iteration No: 3459
# Iteration No: 3460
# We predicted a q value of  56.343616
# We had a loss equal to  127.49546
# Iteration No: 3461
# Iteration No: 3462
# Iteration No: 3463
# Iteration No: 3464
# Iteration No: 3465
# Iteration No: 3466
# Iteration No: 3467
# Iteration No: 3468
# Iteration No: 3469
# Iteration No: 3470
# We predicted a q value of  59.665462
# We had a loss equal to  71.77121
# Iteration No: 3471
# Iteration No: 3472
# Iteration No: 3473
# Iteration No: 3474
# Iteration No: 3475
# Iteration No: 3476
# Iteration No: 3477
# Iteration No: 3478
# Iteration No: 3479
# Iteration No: 3480
# We predicted a q value of  57.86548
# We had a loss equal to  79.45831
# Iteration No: 3481
# Iteration No: 3482
# Iteration No: 3483
# Iteration No: 3484
# Iteration No: 3485
# Iteration No: 3486
# Iteration No: 3487
# Iteration No: 3488
# Iteration No: 3489
# Iteration No: 3490
# We predicted a q value of  61.593056
# We had a loss equal to  116.70946
# Iteration No: 3491
# Iteration No: 3492
# Iteration No: 3493
# Iteration No: 3494
# Iteration No: 3495
# Iteration No: 3496
# Iteration No: 3497
# Iteration No: 3498
# Iteration No: 3499
# Iteration No: 3500
# We predicted a q value of  64.92336
# We had a loss equal to  73.68126
# Iteration No: 3501
# Iteration No: 3502
# Iteration No: 3503
# Iteration No: 3504
# Iteration No: 3505
# Iteration No: 3506
# Iteration No: 3507
# Iteration No: 3508
# Iteration No: 3509
# Iteration No: 3510
# We predicted a q value of  63.41102
# We had a loss equal to  116.70706
# Iteration No: 3511
# Iteration No: 3512
# Iteration No: 3513
# Iteration No: 3514
# Iteration No: 3515
# Iteration No: 3516
# Iteration No: 3517
# Iteration No: 3518
# Iteration No: 3519
# Iteration No: 3520
# We predicted a q value of  68.95646
# We had a loss equal to  106.63341
# Iteration No: 3521
# Iteration No: 3522
# Iteration No: 3523
# Iteration No: 3524
# Iteration No: 3525
# Iteration No: 3526
# Iteration No: 3527
# Iteration No: 3528
# Iteration No: 3529
# Iteration No: 3530
# We predicted a q value of  68.774376
# We had a loss equal to  135.71698
# Iteration No: 3531
# Iteration No: 3532
# Iteration No: 3533
# Iteration No: 3534
# Iteration No: 3535
# Iteration No: 3536
# Iteration No: 3537
# Iteration No: 3538
# Iteration No: 3539
# Iteration No: 3540
# We predicted a q value of  0.0
# We had a loss equal to  153.73987
# Iteration No: 3541
# Iteration No: 3542
# Iteration No: 3543
# Iteration No: 3544
# Iteration No: 3545
# Iteration No: 3546
# Iteration No: 3547
# Iteration No: 3548
# Iteration No: 3549
# Iteration No: 3550
# We predicted a q value of  75.21969
# We had a loss equal to  201.07693
# Iteration No: 3551
# Iteration No: 3552
# Iteration No: 3553
# Iteration No: 3554
# Iteration No: 3555
# Iteration No: 3556
# Iteration No: 3557
# Iteration No: 3558
# Iteration No: 3559
# Iteration No: 3560
# We predicted a q value of  0.0
# We had a loss equal to  113.13789
# Iteration No: 3561
# Iteration No: 3562
# Iteration No: 3563
# Iteration No: 3564
# Iteration No: 3565
# Iteration No: 3566
# Iteration No: 3567
# Iteration No: 3568
# Iteration No: 3569
# Iteration No: 3570
# We predicted a q value of  79.76121
# We had a loss equal to  190.4871
# Iteration No: 3571
# Iteration No: 3572
# Iteration No: 3573
# Iteration No: 3574
# Iteration No: 3575
# Iteration No: 3576
# Iteration No: 3577
# Iteration No: 3578
# Iteration No: 3579
# Iteration No: 3580
# We predicted a q value of  78.45059
# We had a loss equal to  258.74255
# Iteration No: 3581
# Iteration No: 3582
# Iteration No: 3583
# Iteration No: 3584
# Iteration No: 3585
# Iteration No: 3586
# Iteration No: 3587
# Iteration No: 3588
# Iteration No: 3589
# Iteration No: 3590
# We predicted a q value of  80.69076
# We had a loss equal to  164.53851
# Iteration No: 3591
# Iteration No: 3592
# Iteration No: 3593
# Iteration No: 3594
# Iteration No: 3595
# Iteration No: 3596
# Iteration No: 3597
# Iteration No: 3598
# Iteration No: 3599
# Iteration No: 3600
# We predicted a q value of  81.90943
# We had a loss equal to  170.97455
# Iteration No: 3601
# Iteration No: 3602
# Iteration No: 3603
# Iteration No: 3604
# Iteration No: 3605
# Iteration No: 3606
# Iteration No: 3607
# Iteration No: 3608
# Iteration No: 3609
# Iteration No: 3610
# We predicted a q value of  87.77187
# We had a loss equal to  130.71005
# Iteration No: 3611
# Iteration No: 3612
# Iteration No: 3613
# Iteration No: 3614
# Iteration No: 3615
# Iteration No: 3616
# Iteration No: 3617
# Iteration No: 3618
# Iteration No: 3619
# Iteration No: 3620
# We predicted a q value of  0.0
# We had a loss equal to  241.54517
# Iteration No: 3621
# Iteration No: 3622
# Iteration No: 3623
# Iteration No: 3624
# Iteration No: 3625
# Iteration No: 3626
# Iteration No: 3627
# Iteration No: 3628
# Iteration No: 3629
# Iteration No: 3630
# We predicted a q value of  90.666756
# We had a loss equal to  248.5561
# Iteration No: 3631
# Iteration No: 3632
# Iteration No: 3633
# Iteration No: 3634
# Iteration No: 3635
# Iteration No: 3636
# Iteration No: 3637
# Iteration No: 3638
# Iteration No: 3639
# Iteration No: 3640
# We predicted a q value of  0.0
# We had a loss equal to  215.49821
# Iteration No: 3641
# Iteration No: 3642
# Iteration No: 3643
# Iteration No: 3644
# Iteration No: 3645
# Iteration No: 3646
# Iteration No: 3647
# Iteration No: 3648
# Iteration No: 3649
# Iteration No: 3650
# We predicted a q value of  92.33056
# We had a loss equal to  136.35693
# Iteration No: 3651
# Iteration No: 3652
# Iteration No: 3653
# Iteration No: 3654
# Iteration No: 3655
# Iteration No: 3656
# Iteration No: 3657
# Iteration No: 3658
# Lived with maximum time  211
# Earned a total of reward equal to  140.0
# Iteration No: 3659
# Iteration No: 3660
# We predicted a q value of  95.92311
# We had a loss equal to  108.77637
# Iteration No: 3661
# Iteration No: 3662
# Iteration No: 3663
# Iteration No: 3664
# Iteration No: 3665
# Iteration No: 3666
# Iteration No: 3667
# Iteration No: 3668
# Iteration No: 3669
# Iteration No: 3670
# We predicted a q value of  100.55006
# We had a loss equal to  327.6969
# Iteration No: 3671
# Iteration No: 3672
# Iteration No: 3673
# Iteration No: 3674
# Iteration No: 3675
# Iteration No: 3676
# Iteration No: 3677
# Iteration No: 3678
# Iteration No: 3679
# Iteration No: 3680
# We predicted a q value of  98.41802
# We had a loss equal to  396.0502
# Iteration No: 3681
# Iteration No: 3682
# Iteration No: 3683
# Iteration No: 3684
# Iteration No: 3685
# Iteration No: 3686
# Iteration No: 3687
# Iteration No: 3688
# Iteration No: 3689
# Iteration No: 3690
# We predicted a q value of  102.21872
# We had a loss equal to  291.75165
# Iteration No: 3691
# Iteration No: 3692
# Iteration No: 3693
# Iteration No: 3694
# Iteration No: 3695
# Iteration No: 3696
# Iteration No: 3697
# Iteration No: 3698
# Iteration No: 3699
# Iteration No: 3700
# We predicted a q value of  103.102486
# We had a loss equal to  281.84918
# Iteration No: 3701
# Iteration No: 3702
# Iteration No: 3703
# Iteration No: 3704
# Iteration No: 3705
# Iteration No: 3706
# Iteration No: 3707
# Iteration No: 3708
# Iteration No: 3709
# Iteration No: 3710
# We predicted a q value of  106.33407
# We had a loss equal to  366.17468
# Iteration No: 3711
# Iteration No: 3712
# Iteration No: 3713
# Iteration No: 3714
# Iteration No: 3715
# Iteration No: 3716
# Iteration No: 3717
# Iteration No: 3718
# Iteration No: 3719
# Iteration No: 3720
# We predicted a q value of  110.37319
# We had a loss equal to  354.96948
# Iteration No: 3721
# Iteration No: 3722
# Iteration No: 3723
# Iteration No: 3724
# Iteration No: 3725
# Iteration No: 3726
# Iteration No: 3727
# Iteration No: 3728
# Iteration No: 3729
# Iteration No: 3730
# We predicted a q value of  111.403465
# We had a loss equal to  291.13736
# Iteration No: 3731
# Iteration No: 3732
# Iteration No: 3733
# Iteration No: 3734
# Iteration No: 3735
# Iteration No: 3736
# Iteration No: 3737
# Iteration No: 3738
# Iteration No: 3739
# Iteration No: 3740
# We predicted a q value of  113.10992
# We had a loss equal to  505.6802
# Iteration No: 3741
# Iteration No: 3742
# Iteration No: 3743
# Iteration No: 3744
# Iteration No: 3745
# Iteration No: 3746
# Iteration No: 3747
# Iteration No: 3748
# Iteration No: 3749
# Iteration No: 3750
# We predicted a q value of  116.18228
# We had a loss equal to  308.31415
# Iteration No: 3751
# Iteration No: 3752
# Iteration No: 3753
# Iteration No: 3754
# Iteration No: 3755
# Iteration No: 3756
# Iteration No: 3757
# Iteration No: 3758
# Iteration No: 3759
# Iteration No: 3760
# We predicted a q value of  0.0
# We had a loss equal to  372.8979
# Iteration No: 3761
# Iteration No: 3762
# Iteration No: 3763
# Iteration No: 3764
# Iteration No: 3765
# Iteration No: 3766
# Iteration No: 3767
# Iteration No: 3768
# Iteration No: 3769
# Iteration No: 3770
# We predicted a q value of  121.90568
# We had a loss equal to  336.55112
# Iteration No: 3771
# Iteration No: 3772
# Iteration No: 3773
# Iteration No: 3774
# Iteration No: 3775
# Iteration No: 3776
# Iteration No: 3777
# Iteration No: 3778
# Iteration No: 3779
# Iteration No: 3780
# We predicted a q value of  0.0
# We had a loss equal to  500.94666
# Iteration No: 3781
# Iteration No: 3782
# Iteration No: 3783
# Iteration No: 3784
# Iteration No: 3785
# Iteration No: 3786
# Iteration No: 3787
# Iteration No: 3788
# Iteration No: 3789
# Iteration No: 3790
# We predicted a q value of  124.9661
# We had a loss equal to  268.1399
# Iteration No: 3791
# Iteration No: 3792
# Iteration No: 3793
# Iteration No: 3794
# Iteration No: 3795
# Iteration No: 3796
# Iteration No: 3797
# Iteration No: 3798
# Iteration No: 3799
# Iteration No: 3800
# We predicted a q value of  126.84972
# We had a loss equal to  293.91782
# Iteration No: 3801
# Iteration No: 3802
# Lived with maximum time  144
# Earned a total of reward equal to  35.0
# Iteration No: 3803
# Iteration No: 3804
# Iteration No: 3805
# Iteration No: 3806
# Iteration No: 3807
# Iteration No: 3808
# Iteration No: 3809
# Iteration No: 3810
# We predicted a q value of  132.44258
# We had a loss equal to  341.88043
# Iteration No: 3811
# Iteration No: 3812
# Iteration No: 3813
# Iteration No: 3814
# Iteration No: 3815
# Iteration No: 3816
# Iteration No: 3817
# Iteration No: 3818
# Iteration No: 3819
# Iteration No: 3820
# We predicted a q value of  132.57976
# We had a loss equal to  457.79922
# Iteration No: 3821
# Iteration No: 3822
# Iteration No: 3823
# Iteration No: 3824
# Iteration No: 3825
# Iteration No: 3826
# Iteration No: 3827
# Iteration No: 3828
# Iteration No: 3829
# Iteration No: 3830
# We predicted a q value of  131.02933
# We had a loss equal to  793.1177
# Iteration No: 3831
# Iteration No: 3832
# Iteration No: 3833
# Iteration No: 3834
# Iteration No: 3835
# Iteration No: 3836
# Iteration No: 3837
# Iteration No: 3838
# Iteration No: 3839
# Iteration No: 3840
# We predicted a q value of  134.88487
# We had a loss equal to  419.01282
# Iteration No: 3841
# Iteration No: 3842
# Iteration No: 3843
# Iteration No: 3844
# Iteration No: 3845
# Iteration No: 3846
# Iteration No: 3847
# Iteration No: 3848
# Iteration No: 3849
# Iteration No: 3850
# We predicted a q value of  142.18556
# We had a loss equal to  503.09723
# Iteration No: 3851
# Iteration No: 3852
# Iteration No: 3853
# Iteration No: 3854
# Iteration No: 3855
# Iteration No: 3856
# Iteration No: 3857
# Iteration No: 3858
# Iteration No: 3859
# Iteration No: 3860
# We predicted a q value of  0.0
# We had a loss equal to  631.8138
# Iteration No: 3861
# Iteration No: 3862
# Iteration No: 3863
# Iteration No: 3864
# Iteration No: 3865
# Iteration No: 3866
# Iteration No: 3867
# Iteration No: 3868
# Iteration No: 3869
# Iteration No: 3870
# We predicted a q value of  142.70876
# We had a loss equal to  676.9774
# Iteration No: 3871
# Iteration No: 3872
# Iteration No: 3873
# Iteration No: 3874
# Iteration No: 3875
# Iteration No: 3876
# Iteration No: 3877
# Iteration No: 3878
# Iteration No: 3879
# Iteration No: 3880
# We predicted a q value of  0.0
# We had a loss equal to  559.606
# Iteration No: 3881
# Iteration No: 3882
# Iteration No: 3883
# Iteration No: 3884
# Iteration No: 3885
# Iteration No: 3886
# Iteration No: 3887
# Iteration No: 3888
# Iteration No: 3889
# Iteration No: 3890
# We predicted a q value of  0.0
# We had a loss equal to  562.7068
# Iteration No: 3891
# Iteration No: 3892
# Iteration No: 3893
# Iteration No: 3894
# Iteration No: 3895
# Iteration No: 3896
# Iteration No: 3897
# Iteration No: 3898
# Iteration No: 3899
# Iteration No: 3900
# We predicted a q value of  155.7915
# We had a loss equal to  886.67456
# Iteration No: 3901
# Iteration No: 3902
# Iteration No: 3903
# Iteration No: 3904
# Iteration No: 3905
# Iteration No: 3906
# Iteration No: 3907
# Iteration No: 3908
# Iteration No: 3909
# Iteration No: 3910
# We predicted a q value of  158.85057
# We had a loss equal to  622.7894
# Iteration No: 3911
# Iteration No: 3912
# Iteration No: 3913
# Iteration No: 3914
# Iteration No: 3915
# Iteration No: 3916
# Iteration No: 3917
# Iteration No: 3918
# Iteration No: 3919
# Iteration No: 3920
# We predicted a q value of  155.54875
# We had a loss equal to  538.4215
# Iteration No: 3921
# Iteration No: 3922
# Iteration No: 3923
# Iteration No: 3924
# Iteration No: 3925
# Iteration No: 3926
# Iteration No: 3927
# Iteration No: 3928
# Iteration No: 3929
# Iteration No: 3930
# We predicted a q value of  153.57877
# Lived with maximum time  128
# Earned a total of reward equal to  35.0
# We had a loss equal to  591.28076
# Iteration No: 3931
# Iteration No: 3932
# Iteration No: 3933
# Iteration No: 3934
# Iteration No: 3935
# Iteration No: 3936
# Iteration No: 3937
# Iteration No: 3938
# Iteration No: 3939
# Iteration No: 3940
# We predicted a q value of  167.15053
# We had a loss equal to  412.0391
# Iteration No: 3941
# Iteration No: 3942
# Iteration No: 3943
# Iteration No: 3944
# Iteration No: 3945
# Iteration No: 3946
# Iteration No: 3947
# Iteration No: 3948
# Iteration No: 3949
# Iteration No: 3950
# We predicted a q value of  165.60457
# We had a loss equal to  899.1255
# Iteration No: 3951
# Iteration No: 3952
# Iteration No: 3953
# Iteration No: 3954
# Iteration No: 3955
# Iteration No: 3956
# Iteration No: 3957
# Iteration No: 3958
# Iteration No: 3959
# Iteration No: 3960
# We predicted a q value of  169.37985
# We had a loss equal to  781.1436
# Iteration No: 3961
# Iteration No: 3962
# Iteration No: 3963
# Iteration No: 3964
# Iteration No: 3965
# Iteration No: 3966
# Iteration No: 3967
# Iteration No: 3968
# Iteration No: 3969
# Iteration No: 3970
# We predicted a q value of  168.88475
# We had a loss equal to  432.4877
# Iteration No: 3971
# Iteration No: 3972
# Iteration No: 3973
# Iteration No: 3974
# Iteration No: 3975
# Iteration No: 3976
# Iteration No: 3977
# Iteration No: 3978
# Iteration No: 3979
# Iteration No: 3980
# We predicted a q value of  175.39069
# We had a loss equal to  772.48346
# Iteration No: 3981
# Iteration No: 3982
# Iteration No: 3983
# Iteration No: 3984
# Iteration No: 3985
# Iteration No: 3986
# Iteration No: 3987
# Iteration No: 3988
# Iteration No: 3989
# Iteration No: 3990
# We predicted a q value of  177.03542
# We had a loss equal to  605.6267
# Iteration No: 3991
# Iteration No: 3992
# Iteration No: 3993
# Iteration No: 3994
# Iteration No: 3995
# Iteration No: 3996
# Iteration No: 3997
# Iteration No: 3998
# Iteration No: 3999
# Executing loop 3999

# %%
game_instance.load_network("/content/saved.h5")

# %%
stat = game_instance.calculate_mean()
print("Game Statistics")
print(stat)

# %%
#game_instance.simulate2(path="n.mp4", save=True)

# %%
game_instance.simulate2()
